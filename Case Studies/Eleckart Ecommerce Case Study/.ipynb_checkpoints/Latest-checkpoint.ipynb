# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
Eleckart=pd.read_csv("C:/Users/shivali_dalmia/Desktop/UpGrad/GroupCaseStudy/ConsumerElectronics.csv")

# %%
Eleckart.head()
# Out:
#              fsn_id           order_date  Year  Month      order_id  \
# 0  ACCCX3S58G7B5F6P  2015-10-17 15:11:54  2015     10  3.419301e+15
# 1  ACCCX3S58G7B5F6P  2015-10-19 10:07:22  2015     10  1.420831e+15
# 2  ACCCX3S5AHMF55FV  2015-10-20 15:45:56  2015     10  2.421913e+15
# 3  ACCCX3S5AHMF55FV  2015-10-14 12:05:15  2015     10  4.416592e+15
# 4  ACCCX3S5AHMF55FV  2015-10-17 21:25:03  2015     10  4.419525e+15
#
#    order_item_id   gmv  units deliverybdays deliverycdays  \
# 0   3.419301e+15  6400      1            \N            \N
# 1   1.420831e+15  6900      1            \N            \N
# 2   2.421913e+15  1990      1            \N            \N
# 3   4.416592e+15  1690      1            \N            \N
# 4   4.419525e+15  1618      1            \N            \N
#
#   s1_fact.order_payment_type  sla                 cust_id  \
# 0                        COD    5  -1.01299130778588E+018
# 1                        COD    7  -8.99032457905512E+018
# 2                        COD   10   -1.0404429420466E+018
# 3                    Prepaid    4  -7.60496084352714E+018
# 4                    Prepaid    6    2.8945572083453E+018
#
#                   pincode product_analytic_super_category  \
# 0  -7.79175582905735E+018                              CE
# 1   7.33541149097431E+018                              CE
# 2  -7.47768776228657E+018                              CE
# 3  -5.83593163877661E+018                              CE
# 4   5.34735360997242E+017                              CE
#
#   product_analytic_category product_analytic_sub_category  \
# 0           CameraAccessory               CameraAccessory
# 1           CameraAccessory               CameraAccessory
# 2           CameraAccessory               CameraAccessory
# 3           CameraAccessory               CameraAccessory
# 4           CameraAccessory               CameraAccessory
#
#   product_analytic_vertical  product_mrp  product_procurement_sla
# 0              CameraTripod         7190                        0
# 1              CameraTripod         7190                        0
# 2              CameraTripod         2099                        3
# 3              CameraTripod         2099                        3
# 4              CameraTripod         2099                        3

# %%
data_media=pd.read_excel("C:/Users/shivali_dalmia/Desktop/UpGrad/GroupCaseStudy/Media data and other information.xlsx", sheetname='Media Investment', skiprows=[0,1], usecols=range(1,13))

# %%
data_nps=pd.read_excel("C:/Users/shivali_dalmia/Desktop/UpGrad/GroupCaseStudy/Media data and other information.xlsx", sheetname='Monthly NPS Score', skiprows=[0,1],index_col=None, header=None)

# %%
data_media.head()
# Out:
#      Year  Month  Total Investment        TV    Digital  Sponsorship  \
# 0  2015.0    7.0         17.061775  0.215330   2.533014     7.414270
# 1  2015.0    8.0          5.064306  0.006438   1.278074     1.063332
# 2  2015.0    9.0         96.254380  3.879504   1.356528    62.787651
# 3  2015.0   10.0        170.156297  6.144711  12.622480    84.672532
# 4  2015.0   11.0         51.216220  4.220630   1.275469    14.172116
#
#    Content Marketing  Online marketing   Affiliates        SEM  Radio  Other
# 0           0.000933          1.327278     0.547254   5.023697    NaN    NaN
# 1           0.000006          0.129244     0.073684   2.513528    NaN    NaN
# 2           0.610292         16.379990     5.038266   6.202149    NaN    NaN
# 3           3.444075         24.371778     6.973711  31.927011    NaN    NaN
# 4           0.168633         19.561574     6.595767   5.222032    NaN    NaN

# %%
data_nps.head()
# Out:
#             0            1            2            3            4       5   \
# 0          NPS    54.599588    59.987101    46.925419    44.398389    47.0
# 1  Stock Index  1177.000000  1206.000000  1101.000000  1210.000000  1233.0
#
#        6            7            8           9            10           11  \
# 0    45.8    47.093031    50.327406    49.02055    51.827605    47.306951
# 1  1038.0  1052.000000  1222.000000  1015.00000  1242.000000  1228.000000
#
#             12
# 0    50.516687
# 1  1194.000000

# %%
Eleckart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1648824 entries, 0 to 1648823
# Data columns (total 20 columns):
# fsn_id                             1648824 non-null object
# order_date                         1648824 non-null object
# Year                               1648824 non-null int64
# Month                              1648824 non-null int64
# order_id                           1648824 non-null float64
# order_item_id                      1648824 non-null float64
# gmv                                1648824 non-null object
# units                              1648824 non-null int64
# deliverybdays                      1648824 non-null object
# deliverycdays                      1648824 non-null object
# s1_fact.order_payment_type         1648824 non-null object
# sla                                1648824 non-null int64
# cust_id                            1648824 non-null object
# pincode                            1648824 non-null object
# product_analytic_super_category    1648824 non-null object
# product_analytic_category          1648824 non-null object
# product_analytic_sub_category      1648824 non-null object
# product_analytic_vertical          1648824 non-null object
# product_mrp                        1648824 non-null int64
# product_procurement_sla            1648824 non-null int64
# dtypes: float64(2), int64(6), object(12)
# memory usage: 251.6+ MB

# %%
data_media.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 12 columns):
# Year                 12 non-null float64
# Month                12 non-null float64
# Total Investment     12 non-null float64
# TV                   13 non-null float64
# Digital              12 non-null float64
# Sponsorship          12 non-null float64
# Content Marketing    12 non-null float64
# Online marketing     12 non-null float64
#  Affiliates          12 non-null float64
# SEM                  12 non-null float64
# Radio                3 non-null float64
# Other                3 non-null float64
# dtypes: float64(12)
# memory usage: 1.6 KB

# %%
data_nps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 13 columns):
# 0     2 non-null object
# 1     2 non-null float64
# 2     2 non-null float64
# 3     2 non-null float64
# 4     2 non-null float64
# 5     2 non-null float64
# 6     2 non-null float64
# 7     2 non-null float64
# 8     2 non-null float64
# 9     2 non-null float64
# 10    2 non-null float64
# 11    2 non-null float64
# 12    2 non-null float64
# dtypes: float64(12), object(1)
# memory usage: 288.0+ bytes

# %% [markdown]
# ### Data Preparation

# %%
data_media
# Out:
#       Year  Month  Total Investment         TV    Digital  Sponsorship  \
# 0   2015.0    7.0         17.061775   0.215330   2.533014     7.414270
# 1   2015.0    8.0          5.064306   0.006438   1.278074     1.063332
# 2   2015.0    9.0         96.254380   3.879504   1.356528    62.787651
# 3   2015.0   10.0        170.156297   6.144711  12.622480    84.672532
# 4   2015.0   11.0         51.216220   4.220630   1.275469    14.172116
# 5   2015.0   12.0        106.745312   5.397502   3.063360    56.705419
# 6   2016.0    1.0         74.196000   4.380000   0.456000     4.200000
# 7   2016.0    2.0         48.052000   2.586008   1.912651    11.725555
# 8   2016.0    3.0        100.024621   9.300000   2.100000    41.590000
# 9   2016.0    4.0         56.848241   5.205196   0.871892    24.308354
# 10  2016.0    5.0         78.057000   1.370000   0.770000    31.680000
# 11  2016.0    6.0         42.834216   1.662717   1.420761    25.048541
# 12     NaN    NaN               NaN        NaN        NaN          NaN
# 13     NaN    NaN               NaN        NaN        NaN          NaN
# 14     NaN    NaN               NaN        NaN        NaN          NaN
# 15     NaN    NaN               NaN  18.549000        NaN          NaN
#
#     Content Marketing  Online marketing   Affiliates        SEM  Radio  \
# 0            0.000933          1.327278     0.547254   5.023697    NaN
# 1            0.000006          0.129244     0.073684   2.513528    NaN
# 2            0.610292         16.379990     5.038266   6.202149    NaN
# 3            3.444075         24.371778     6.973711  31.927011    NaN
# 4            0.168633         19.561574     6.595767   5.222032    NaN
# 5            1.067307         22.503756     6.826938  11.181030    NaN
# 6            0.900000         22.900000     7.370000   4.200000   2.70
# 7            0.596771         19.892366     6.465019   4.873630    NaN
# 8            0.370000         18.437818     6.217667   5.193591   0.87
# 9            0.034876         16.514510     5.693456   4.219958    NaN
# 10           0.790000         23.650000     6.800000   6.910000   1.10
# 11           0.045081          7.971300     2.768023   3.735516    NaN
# 12                NaN               NaN          NaN        NaN    NaN
# 13                NaN               NaN          NaN        NaN    NaN
# 14                NaN               NaN          NaN        NaN    NaN
# 15                NaN               NaN          NaN        NaN    NaN
#
#         Other
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6   27.090000
# 7         NaN
# 8   15.945545
# 9         NaN
# 10   4.987000
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN

# %%
data_media["Year_month"]=data_media["Year"].map(str) + "-" +data_media["Month"].map(str)

# %%
data_media[["Year", "Month"]] = data_media[["Year", "Month"]].apply(pd.to_numeric)

# %%
plt.figure(figsize=(10,6))
sns.barplot(y='Total Investment', x='Year_month',data=data_media)

# %% [markdown]
# ##### August has the lowest spending
# ##### September, October, December have the highest spending

# %%
#Replacing NA values by zero in Radio and Others investment details
data_media.fillna(0, inplace=True)
data_media
# Out:
#       Year  Month  Total Investment         TV    Digital  Sponsorship  \
# 0   2015.0    7.0         17.061775   0.215330   2.533014     7.414270
# 1   2015.0    8.0          5.064306   0.006438   1.278074     1.063332
# 2   2015.0    9.0         96.254380   3.879504   1.356528    62.787651
# 3   2015.0   10.0        170.156297   6.144711  12.622480    84.672532
# 4   2015.0   11.0         51.216220   4.220630   1.275469    14.172116
# 5   2015.0   12.0        106.745312   5.397502   3.063360    56.705419
# 6   2016.0    1.0         74.196000   4.380000   0.456000     4.200000
# 7   2016.0    2.0         48.052000   2.586008   1.912651    11.725555
# 8   2016.0    3.0        100.024621   9.300000   2.100000    41.590000
# 9   2016.0    4.0         56.848241   5.205196   0.871892    24.308354
# 10  2016.0    5.0         78.057000   1.370000   0.770000    31.680000
# 11  2016.0    6.0         42.834216   1.662717   1.420761    25.048541
# 12     0.0    0.0          0.000000   0.000000   0.000000     0.000000
# 13     0.0    0.0          0.000000   0.000000   0.000000     0.000000
# 14     0.0    0.0          0.000000   0.000000   0.000000     0.000000
# 15     0.0    0.0          0.000000  18.549000   0.000000     0.000000
#
#     Content Marketing  Online marketing   Affiliates        SEM  Radio  \
# 0            0.000933          1.327278     0.547254   5.023697   0.00
# 1            0.000006          0.129244     0.073684   2.513528   0.00
# 2            0.610292         16.379990     5.038266   6.202149   0.00
# 3            3.444075         24.371778     6.973711  31.927011   0.00
# 4            0.168633         19.561574     6.595767   5.222032   0.00
# 124     0.0    0.0    Radio   0.000000
# 125     0.0    0.0    Radio   0.000000
# 126     0.0    0.0    Radio   0.000000
# 127     0.0    0.0    Radio   0.000000
# 128  2015.0    7.0    Other   0.000000
# 129  2015.0    8.0    Other   0.000000
# 130  2015.0    9.0    Other   0.000000
# 131  2015.0   10.0    Other   0.000000
# 132  2015.0   11.0    Other   0.000000
# 133  2015.0   12.0    Other   0.000000
# 134  2016.0    1.0    Other  27.090000
# 135  2016.0    2.0    Other   0.000000
# 136  2016.0    3.0    Other  15.945545
# 137  2016.0    4.0    Other   0.000000
# 138  2016.0    5.0    Other   4.987000
# 139  2016.0    6.0    Other   0.000000
# 140     0.0    0.0    Other   0.000000
# 141     0.0    0.0    Other   0.000000
# 142     0.0    0.0    Other   0.000000
# 143     0.0    0.0    Other   0.000000
#
# [144 rows x 4 columns]

# %%
melt=pd.melt(data_media, id_vars=['Year','Month'],value_vars= data_media.columns[3:12])
plt.figure(figsize=(10,8))
sns.barplot(y='value',x='Month', hue='variable',data=melt)

# %%
#Criteria 1: Use the data from July 2015 to June 2016
Eleckart['order_date']= pd.to_datetime(Eleckart['order_date'], errors='coerce')
mask = (Eleckart['order_date'] >= '2015-07-01') & (Eleckart['order_date'] <= '2016-06-30')
Eleckart= Eleckart.loc[mask]
Eleckart.head(5)
# Out:
#              fsn_id          order_date  Year  Month      order_id  \
# 0  ACCCX3S58G7B5F6P 2015-10-17 15:11:54  2015     10  3.419301e+15
# 1  ACCCX3S58G7B5F6P 2015-10-19 10:07:22  2015     10  1.420831e+15
# 2  ACCCX3S5AHMF55FV 2015-10-20 15:45:56  2015     10  2.421913e+15
# 3  ACCCX3S5AHMF55FV 2015-10-14 12:05:15  2015     10  4.416592e+15
# 4  ACCCX3S5AHMF55FV 2015-10-17 21:25:03  2015     10  4.419525e+15
#
#    order_item_id   gmv  units deliverybdays deliverycdays  \
# 0   3.419301e+15  6400      1            \N            \N
# 1   1.420831e+15  6900      1            \N            \N
# 2   2.421913e+15  1990      1            \N            \N
# 3   4.416592e+15  1690      1            \N            \N
# 4   4.419525e+15  1618      1            \N            \N
#
#   s1_fact.order_payment_type  sla                 cust_id  \
# 0                        COD    5  -1.01299130778588E+018
# 1                        COD    7  -8.99032457905512E+018
# 2                        COD   10   -1.0404429420466E+018
# 3                    Prepaid    4  -7.60496084352714E+018
# 4                    Prepaid    6    2.8945572083453E+018
#
#                   pincode product_analytic_super_category  \
# 0  -7.79175582905735E+018                              CE
# 1   7.33541149097431E+018                              CE
# 2  -7.47768776228657E+018                              CE
# 3  -5.83593163877661E+018                              CE
# 4   5.34735360997242E+017                              CE
#
#   product_analytic_category product_analytic_sub_category  \
# 0           CameraAccessory               CameraAccessory
# 1           CameraAccessory               CameraAccessory
# 2           CameraAccessory               CameraAccessory
# 3           CameraAccessory               CameraAccessory
# 4           CameraAccessory               CameraAccessory
#
#   product_analytic_vertical  product_mrp  product_procurement_sla
# 0              CameraTripod         7190                        0
# 1              CameraTripod         7190                        0
# 2              CameraTripod         2099                        3
# 3              CameraTripod         2099                        3
# 4              CameraTripod         2099                        3

# %%
Eleckart.shape
# Out:
# (1644943, 20)

# %%
#Writing the extracted data July 2015 to June 2016 to a new file called ConsumerElectronicsExtracted.csv'
Eleckart.to_csv('ConsumerElectronicsExtracted.csv')

# %%
#Let us address the \N values in the data set ConsumerElectronicsExtracted.csv by replacing it with NA values.
Eleckart1= pd.read_csv('ConsumerElectronicsExtracted.csv', na_values=['\\N',''])
Eleckart1.drop(["Unnamed: 0"], axis = 1, inplace = True)
Eleckart1.head(5)
# Out:
#              fsn_id           order_date  Year  Month      order_id  \
# 0  ACCCX3S58G7B5F6P  2015-10-17 15:11:54  2015     10  3.419301e+15
# 1  ACCCX3S58G7B5F6P  2015-10-19 10:07:22  2015     10  1.420831e+15
# 2  ACCCX3S5AHMF55FV  2015-10-20 15:45:56  2015     10  2.421913e+15
# 3  ACCCX3S5AHMF55FV  2015-10-14 12:05:15  2015     10  4.416592e+15
# 4  ACCCX3S5AHMF55FV  2015-10-17 21:25:03  2015     10  4.419525e+15
#
#    order_item_id   gmv  units  deliverybdays  deliverycdays  \
# 0   3.419301e+15  6400      1            NaN            NaN
# 1   1.420831e+15  6900      1            NaN            NaN
# 2   2.421913e+15  1990      1            NaN            NaN
# 3   4.416592e+15  1690      1            NaN            NaN
# 4   4.419525e+15  1618      1            NaN            NaN
#
#   s1_fact.order_payment_type  sla                 cust_id  \
# 0                        COD    5  -1.01299130778588E+018
# 1                        COD    7  -8.99032457905512E+018
# 2                        COD   10   -1.0404429420466E+018
# 3                    Prepaid    4  -7.60496084352714E+018
# 4                    Prepaid    6    2.8945572083453E+018
#
#                   pincode product_analytic_super_category  \
# 0  -7.79175582905735E+018                              CE
# 1   7.33541149097431E+018                              CE
# 2  -7.47768776228657E+018                              CE
# 3  -5.83593163877661E+018                              CE
# 4   5.34735360997242E+017                              CE
#
#   product_analytic_category product_analytic_sub_category  \
# 0           CameraAccessory               CameraAccessory
# 1           CameraAccessory               CameraAccessory
# 2           CameraAccessory               CameraAccessory
# 3           CameraAccessory               CameraAccessory
# 4           CameraAccessory               CameraAccessory
#
#   product_analytic_vertical  product_mrp  product_procurement_sla
# 0              CameraTripod         7190                        0
# 1              CameraTripod         7190                        0
# 2              CameraTripod         2099                        3
# 3              CameraTripod         2099                        3
# 4              CameraTripod         2099                        3

# %%
#Extracting the day and week from the given data set
Eleckart1['order_date']= pd.to_datetime(Eleckart1['order_date'], errors='coerce')
Eleckart1['Day'] = Eleckart1['order_date'].dt.day
Eleckart1['Week'] = Eleckart1['order_date'].dt.week
Eleckart1[['Day','Week']].head (5)
# Out:
#    Day  Week
# 0   17    42
# 1   19    43
# 2   20    43
# 3   14    42
# 4   17    42

# %%
print('The minimum order date {}. The maximum order date {}.'.format(
    Eleckart1.order_date.min(), Eleckart1.order_date.max()))
# Out:
# The minimum order date 2015-07-01 00:36:11. The maximum order date 2016-06-29 23:59:22.

# %%
#Check the count of missing values in the columns
Eleckart1.isnull().sum()
# Out:
# fsn_id                                   0
# order_date                               0
# Year                                     0
# Month                                    0
# order_id                                 0
# order_item_id                            0
# gmv                                      0
# units                                    0
# deliverybdays                      1312149
# deliverycdays                      1312148
# s1_fact.order_payment_type               0
# sla                                      0
# cust_id                                  0
# pincode                                  0
# product_analytic_super_category          0
# product_analytic_category                0
# product_analytic_sub_category            0
# product_analytic_vertical             5821
# product_mrp                              0
# product_procurement_sla                  0
# Day                                      0
# Week                                     0
# dtype: int64

# %%
#Calculating the percentage of null values
round(100*(Eleckart1.isnull().sum()/len(Eleckart1.index)), 2)
# Out:
# fsn_id                              0.00
# order_date                          0.00
# Year                                0.00
# Month                               0.00
# order_id                            0.00
# order_item_id                       0.00
# gmv                                 0.00
# units                               0.00
# deliverybdays                      79.77
# deliverycdays                      79.77
# s1_fact.order_payment_type          0.00
# sla                                 0.00
# cust_id                             0.00
# pincode                             0.00
# product_analytic_super_category     0.00
# product_analytic_category           0.00
# product_analytic_sub_category       0.00
# product_analytic_vertical           0.35
# product_mrp                         0.00
# product_procurement_sla             0.00
# Day                                 0.00
# Week                                0.00
# dtype: float64

# %% [markdown]
# From the above it is clear that % of null values are as follows
# ##### deliverybdays- 79.77%
# ##### deliverycdays- 79.77%
# ##### product_analytic_vertical- 0.35%
#
# We have a good healthy dataset, thus removal of these null values will not impact in the end result.
# Thus, we are removing them.

# %%
Eleckart1 = Eleckart1[~Eleckart1.deliverybdays.isnull()]
Eleckart1 = Eleckart1[~Eleckart1.deliverycdays.isnull()]
Eleckart1 = Eleckart1[~Eleckart1.product_analytic_vertical.isnull()]

# %%
Eleckart1.isnull().sum()
# Out:
# fsn_id                             0
# order_date                         0
# Year                               0
# Month                              0
# order_id                           0
# order_item_id                      0
# gmv                                0
# units                              0
# deliverybdays                      0
# deliverycdays                      0
# s1_fact.order_payment_type         0
# sla                                0
# cust_id                            0
# pincode                            0
# product_analytic_super_category    0
# product_analytic_category          0
# product_analytic_sub_category      0
# product_analytic_vertical          0
# product_mrp                        0
# product_procurement_sla            0
# Day                                0
# Week                               0
# dtype: int64

# %%
#Let us check the number of duplicate values in the dataframe
Eleckart1.duplicated().sum()
# Out:
# 50

# %%
duplicateRowsDF = Eleckart1[Eleckart1.duplicated(keep=False)]
print("All Duplicate Rows based on all columns are :")
duplicateRowsDF
# Out:
# All Duplicate Rows based on all columns are :
#                    fsn_id          order_date  Year  Month      order_id  \
# 944705   ACCDH7MFZJGRWJCW 2016-04-27 00:19:25  2016      4  3.575842e+15
# 944830   ACCDH7MFZJGRWJCW 2016-04-27 00:19:25  2016      4  3.575842e+15
# 1033340  AVMDX6TFZZQM7SXJ 2016-04-27 00:43:52  2016      4  3.580256e+15
# 1033341  AVMDX6TFZZQM7SXJ 2016-04-27 00:43:52  2016      4  3.580256e+15
# 1033407  AVMDX6TFZZQM7SXJ 2016-04-27 00:43:52  2016      4  3.580256e+15
# 1033492  AVMDX6TFZZQM7SXJ 2016-04-27 00:43:52  2016      4  3.580256e+15
# 1033640  AVMDX6TFZZQM7SXJ 2016-04-27 00:43:52  2016      4  3.580256e+15
# 1047416  GAME5UVFVTCJQ95Z 2016-04-27 00:38:59  2016      4  1.566052e+15
# 1047433  GAME5UVFVTCJQ95Z 2016-04-27 00:38:59  2016      4  1.566052e+15
# 1047469  GAME5UVFVTCJQ95Z 2016-04-27 00:38:59  2016      4  1.566052e+15
# 1047527  GAME5UVFVTCJQ95Z 2016-04-27 00:38:59  2016      4  1.566052e+15
# 1047433                              CE                 GameCDDVD
# 1047469                              CE                 GameCDDVD
# 1047527                              CE                 GameCDDVD
# 1047566                              CE                 GameCDDVD
# 1049248                              CE                 GameCDDVD
# 1049284                              CE                 GameCDDVD
# 1049374                              CE                 GameCDDVD
# 1049558                              CE                 GameCDDVD
# 1067154                              CE        EntertainmentSmall
# 1067180                              CE        EntertainmentSmall
# 1067181                              CE        EntertainmentSmall
# 1067208                              CE        EntertainmentSmall
# 1438789                              CE        EntertainmentSmall
# 1444619                              CE        EntertainmentSmall
# 1446134                              CE        EntertainmentSmall
# 1448156                              CE           CameraAccessory
# 1449026                              CE           CameraAccessory
# 1452731                              CE        EntertainmentSmall
# 1456159                              CE            GamingHardware
# 1457023                              CE        EntertainmentSmall
# 1462302                              CE        EntertainmentSmall
# 1463082                              CE        EntertainmentSmall
# ...                                 ...                       ...
# 1557558                              CE        EntertainmentSmall
# 1560986                              CE            GamingHardware
# 1561850                              CE        EntertainmentSmall
# 1567129                              CE        EntertainmentSmall
# 1567909                              CE        EntertainmentSmall
# 1569527                              CE           CameraAccessory
# 1574768                              CE        EntertainmentSmall
# 1578687                              CE        EntertainmentSmall
# 1579480                              CE        EntertainmentSmall
# 1579812                              CE            GamingHardware
# 1585737                              CE            GamingHardware
# 1588157                              CE            GamingHardware
# 1588824                              CE           CameraAccessory
# 1588991                              CE           CameraAccessory
# 1589354                              CE           CameraAccessory
# 1589736                              CE           CameraAccessory
# 1591852                              CE           CameraAccessory
# 1591942                              CE           CameraAccessory
# 1593119                              CE            GamingHardware
# 1593616                              CE        EntertainmentSmall
# 1594547                              CE            GamingHardware
# 1594637                              CE            GamingHardware
# 1596288                              CE        EntertainmentSmall
# 1602393                              CE            GamingHardware
# 1603093                              CE           CameraAccessory
# 1607376                              CE        EntertainmentSmall
# 1613234                              CE        EntertainmentSmall
# 1621502                              CE                    Camera
# 1622961                              CE                    Camera
# 1629747                              CE                 GameCDDVD
#
#         product_analytic_sub_category product_analytic_vertical product_mrp  \
# 944705                GamingAccessory                   GamePad         410
# 944830                GamingAccessory                   GamePad         410
# 1033340                          Game              PhysicalGame        4999
# 1033341                          Game              PhysicalGame        4999
# 1033407                          Game              PhysicalGame        4999
# 1033492                          Game              PhysicalGame        4999
# 1033640                          Game              PhysicalGame        4999
# 1047416                          Game              PhysicalGame        3499
# 1047433                          Game              PhysicalGame        3499
# 1047469                          Game              PhysicalGame        3499
# 1047527                          Game              PhysicalGame        3499
# 1047566                          Game              PhysicalGame        3499
# 1049248                          Game              PhysicalGame        4499
# 1049284                          Game              PhysicalGame        4499
# 1049374                          Game              PhysicalGame        4499
# 1049558                          Game              PhysicalGame        4499
# 1067154                  TVVideoSmall              VideoGlasses         500
# 1067180                  TVVideoSmall              VideoGlasses         500
# 1067181                  TVVideoSmall              VideoGlasses         500
# 1067208                  TVVideoSmall              VideoGlasses         500
# 1438789                       Speaker             LaptopSpeaker         699
# 1444619                       Speaker             LaptopSpeaker        3499
# 1446134                       Speaker             LaptopSpeaker         899
# 1448156               CameraAccessory                 CameraBag        1100
# 1449026               CameraAccessory             CameraBattery         250
# 1452731                       Speaker             MobileSpeaker        7999
# 1456159               GamingAccessory               GamingMouse        1370
# 1457023                     HomeAudio          HomeAudioSpeaker        3779
# 1462302                       Speaker             LaptopSpeaker         399
# 1463082                       Speaker             LaptopSpeaker         599
# ...                               ...                       ...         ...
# 1557558                       Speaker             MobileSpeaker        7999
# 1560986               GamingAccessory               GamingMouse        1370
# 1561850                     HomeAudio          HomeAudioSpeaker        3779
# 1567129                       Speaker             LaptopSpeaker         399
# 1567909                       Speaker             LaptopSpeaker         599
# 1569527                 CameraStorage   CameraStorageMemoryCard         299
# 1574768                       Speaker             MobileSpeaker        1999
# 1578687                       Speaker             MobileSpeaker        3490
# 1579480                       Speaker             LaptopSpeaker        1599
# 1579812               GamingAccessory               GamingMouse         799
# 1585737               GamingAccessory                   GamePad         250
# 1588157               GamingAccessory             GamingHeadset         999
# 1588824               CameraAccessory              CameraTripod        1000
# 1588991               CameraAccessory              CameraTripod        1990
# 1589354               CameraAccessory              CameraTripod        1490
# 1589736               CameraAccessory              CameraTripod        1399
# 1591852               CameraAccessory              CameraTripod        1990
# 1591942               CameraAccessory              CameraTripod        1990
# 1593119               GamingAccessory       TVOutCableAccessory         799
# 1593616                       Speaker             MobileSpeaker         999
# 1594547               GamingAccessory                   GamePad        1599
# 1594637               GamingAccessory                   GamePad        1799
# 1596288                       Speaker             LaptopSpeaker         799
# 1602393               GamingAccessory                   GamePad        3000
# 1603093               CameraAccessory                     Flash        1299
# 1607376                       Speaker             LaptopSpeaker       11990
# 1613234                AudioMP3Player            AudioMP3Player        1669
# 1621502                        Camera             Point & Shoot       34990
# 1622961                        Camera                      DSLR       40000
# 1629747                          Game              PhysicalGame         999
#
#         product_procurement_sla  Day  Week
# 944705                        1   27    17
# 944830                        1   27    17
# 1033340                       5   27    17
# 1033341                       5   27    17
# 1033407                       5   27    17
# 1033492                       5   27    17
# 1033640                       5   27    17
# 1047416                       6   27    17
# 1047433                       6   27    17
# 1047469                       6   27    17
# 1047527                       6   27    17
# 1047566                       6   27    17
# 1049248                       1   27    17
# 1049284                       1   27    17
# 1049374                       1   27    17
# 1049558                       1   27    17
# 1067154                       5   27    17
# 1067180                       5   27    17
# 1067181                       5   27    17
# 1067208                       5   27    17
# 1438789                       7   27    17
# 1444619                       5   27    17
# 1446134                       2   27    17
# 1448156                       5   27    17
# 1449026                       3    4     5
# 1452731                       2   27    17
# 1456159                       0   27    17
# 1457023                       1   22     8
# 1462302                       3   30    40
# 1463082                       5    9    37
# ...                         ...  ...   ...
# 1557558                       2   27    17
# 1560986                       0   27    17
# 1561850                       1   22     8
# 1567129                       3   30    40
# 1567909                       5    9    37
# 1569527                       2   27    17
# 1574768                       2    7    37
# 1578687                       1   30    40
# 1579480                       3   24    39
# 1579812                       5   27    17
# 1585737                       2   26    17
# 1588157                       4   30    40
# 1588824                       1   27    17
# 1588991                       1   22     8
# 1589354                       1   27    17
# 1589736                       3   16    11
# 1591852                       2   27    17
# 1591942                       2    4     5
# 1593119                       1   27    17
# 1593616                       2    7    37
# 1594547                       2   27    17
# 1594637                       0   12     6
# 1596288                       4   24    39
# 1602393                       2    9    14
# 1603093                       4   20    38
# 1607376                       5   27    17
# 1613234                       4   27    17
# 1621502                      -1   27    17
# 1622961                       2   27    17
# 1629747                      -1    3    36
#
# [90 rows x 22 columns]

# %%
#From the above list we can see that there are duplicate rows and we intend to keep only one of them.
#Dropping duplicates and keeping the first occurance
Eleckart1.drop_duplicates(keep = 'first', inplace = True)

# %%
#There are no duplicate values in the dataframe.
Eleckart1.duplicated().sum()
# Out:
# 0

# %%
Eleckart1.head(5)
# Out:
#                  fsn_id          order_date  Year  Month      order_id  \
# 706    ACCCX3SU22JG8NJX 2015-10-26 13:06:37  2015     10  3.419100e+15
# 9726   ACCDF2Z7KXGSZEP7 2016-02-03 14:39:53  2016      2  4.415891e+15
# 11094  ACCDFYZ479GFENYC 2016-04-27 01:33:04  2016      4  4.418233e+15
# 11693  ACCDFZEJMYKKUZ8J 2015-10-18 18:14:05  2015     10  3.420272e+15
# 12883  ACCDH7MFZJGRWJCW 2015-10-16 18:27:57  2015     10  3.418556e+15
#
#        order_item_id   gmv  units  deliverybdays  deliverycdays  ...  \
# 706     3.419100e+15   470      1            5.0            6.0  ...
# 9726    4.415891e+15   384      1            5.0            6.0  ...
# 11094   4.418233e+15   306      1            4.0            5.0  ...
# 11693   3.420272e+15  2442      1           12.0           14.0  ...
# 12883   3.418556e+15   268      1            6.0            7.0  ...
#
#                       cust_id                 pincode  \
# 706     9.08246875057758E+018  -7.82411064429225E+018
# 9726   -5.50337769581818E+017  -8.03408849241778E+018
# 11094   3.91175066210113E+018  -7.84370947414129E+018
# 11693   7.11103782298018E+018     5.186887196114E+018
# 12883  -5.25902954913596E+018   7.47752021619299E+018
#
#       product_analytic_super_category product_analytic_category  \
# 706                                CE           CameraAccessory
# 9726                               CE            GamingHardware
# 11094                              CE           CameraAccessory
# 11693                              CE        EntertainmentSmall
# 12883                              CE            GamingHardware
#
#       product_analytic_sub_category product_analytic_vertical product_mrp  \
# 706                 CameraAccessory             CameraBattery        1545
# 9726                GamingAccessory                   GamePad         350
# 11094               CameraAccessory      CameraBatteryCharger         300
# 11693                       Speaker             LaptopSpeaker        5999
# 12883               GamingAccessory                   GamePad         410
#
#       product_procurement_sla  Day  Week
# 706                         1   26    44
# 9726                        3    3     5
# 11094                       1   27    17
# 11693                       1   18    42
# 12883                       1   16    42
#
# [5 rows x 22 columns]

# %%
Eleckart1.shape
# Out:
# (331596, 22)

# %%
# Percentage of data left from original dataset for analysis
(len(Eleckart1.index)/1648824)*100
# Out:
# 20.111060974367184

# %%
Eleckart1["order_date"] = Eleckart1["order_date"].astype(str)

# %% [markdown]
# #### Handling Zero GMV entries

# %%
Eleckart1['gmv'].count()
# Out:
# 331596

# %%
# Replacing Empty spaces with NaNs
Eleckart1['gmv'].replace(r'\s+', np.nan,regex=True,inplace=True)
# Removing rows where GMV Values are Null
Eleckart1=Eleckart1[~Eleckart1.gmv.isnull()]

# %%
print("Count of rows with gmv value equal to '0' = {}".format(Eleckart1[Eleckart1['gmv']==0].shape[0]))
#Removing these rows
Eleckart1=Eleckart1[Eleckart1['gmv']!=0]
print("After removing such rows")
Eleckart1[Eleckart1['gmv']==0].shape[0]
# Out:
# Count of rows with gmv value equal to '0' = 83
# After removing such rows
# 0

# %%
Eleckart1['gmv'].dtype
# Out:
# dtype('O')

# %%
Eleckart1['gmv'] = pd.to_numeric(Eleckart1['gmv'], errors='coerce')

# %%
Eleckart1.plot(y=['gmv','product_mrp'],use_index=True,figsize=(12,10))

# %% [markdown]
# #### Some GMV Values are greater than their corresponding MRPs, we'll replace such MRPs with GMVs

# %%
Eleckart1['product_mrp']=np.where(Eleckart1['gmv']>Eleckart1['product_mrp'],Eleckart1['gmv'],Eleckart1['product_mrp'])

# %%
Eleckart1.plot(y=['gmv','product_mrp'],use_index=True,figsize=(12,10))

# %%
Eleckart1['s1_fact.order_payment_type'].count()
# Out:
# 331511

# %%
Eleckart1['s1_fact.order_payment_type'].unique().tolist()
# Out:
# ['Prepaid', 'COD']

# %%
#Comparing the percentage
Eleckart1['s1_fact.order_payment_type'].value_counts()/Eleckart1['s1_fact.order_payment_type'].count()
# Out:
# COD        0.539487
# Prepaid    0.460513
# Name: s1_fact.order_payment_type, dtype: float64

# %% [markdown]
# ##### From the above output it is clear that COD (Cash on Delivery is the preferred one).

# %%
# Checking the number of rows
Eleckart1['sla'].count()
# Out:
# 331511

# %% [markdown]
# #### Inspecting and preparing pincode column

# %%
# Checking the number of unique pincodes
Eleckart1['pincode'].nunique()
# Out:
# 7737

# %%
# Replacing Empty spaces with NaNs
Eleckart1['pincode'].replace(r'\s+', np.nan,regex=True,inplace=True)
# Removing rows where pincode Values are Null
Eleckart1=Eleckart1[~Eleckart1.pincode.isnull()]

# %%
Eleckart1['pincode'].nunique()
# Out:
# 7737

# %% [markdown]
# ##### There is a total of 7738 unique pincodes before removal of blank spaces
# ##### There is a total of 7719 unique pincodes after removal of blank spaces

# %% [markdown]
# #### Inspecting Customer IDs

# %%
# Checking for unique customer IDs
Eleckart1['cust_id'].nunique()
# Out:
# 289013

# %%
# Replacing Empty spaces with NaNs
Eleckart1['cust_id'].replace(r'\s+', np.nan,regex=True,inplace=True)
# Removing rows where pincode Values are Null
Eleckart1=Eleckart1[~Eleckart1.cust_id.isnull()]

# %%
print("Count of rows with Customer ID value equal to '0' = {}".format(Eleckart1[Eleckart1['cust_id']==0].shape[0]))
#Removing these rows
Eleckart1=Eleckart1[Eleckart1['cust_id']!=0]
print("After removing such rows")
Eleckart1[Eleckart1['cust_id']==0].shape[0]
# Out:
# Count of rows with Customer ID value equal to '0' = 0
# After removing such rows
# 0

# %%
Eleckart['cust_id'].describe()
# Out:
# count     1644943
# unique    1250572
# top
# freq         4904
# Name: cust_id, dtype: object

# %% [markdown]
# #### Inspecting MRP

# %%
# Checking the distribution of product_mrp
Eleckart1['product_mrp'].describe()
# Out:
# count    331511.000000
# mean       3979.688004
# std        8489.659283
# min          40.000000
# 25%         800.000000
# 50%        1599.000000
# 75%        3490.000000
# max      280000.000000
# Name: product_mrp, dtype: float64

# %% [markdown]
# ##### Some MRP values are given as Zero, which is an anomaly

# %%
mrp_count = Eleckart1['product_mrp'].count()
print("mrp_count {}" .format(mrp_count))
# Out:
# mrp_count 331511

# %%
Eleckart1[Eleckart1['product_mrp']==0]
# Out:
# Empty DataFrame
# Columns: [fsn_id, order_date, Year, Month, order_id, order_item_id, gmv, units, deliverybdays, deliverycdays, s1_fact.order_payment_type, sla, cust_id, pincode, product_analytic_super_category, product_analytic_category, product_analytic_sub_category, product_analytic_vertical, product_mrp, product_procurement_sla, Day, Week]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# #### A Total of 903 rows have MRPs as Zero
# These rows can be removed

# %%
Eleckart1=Eleckart1[Eleckart1['product_mrp']!=0]

# %%
# Checking super_category
Eleckart1['product_analytic_super_category'].nunique()
# Out:
# 1

# %% [markdown]
# #### There is only one single value in the  product_analytic_super_category

# %%
Eleckart1['product_analytic_super_category'].unique().tolist()
# Out:
# ['CE']

# %%
#Product analytic category
Eleckart1['product_analytic_category'].value_counts()
# Out:
# EntertainmentSmall    174439
# CameraAccessory        60201
# GamingHardware         50532
# GameCDDVD              28268
# Camera                 18071
# Name: product_analytic_category, dtype: int64

# %%
Eleckart1['product_analytic_sub_category'].describe()
# Out:
# count      331511
# unique         14
# top       Speaker
# freq        94967
# Name: product_analytic_sub_category, dtype: object

# %%
Eleckart1['product_analytic_sub_category'].value_counts()
# Out:
# Speaker                94967
# CameraAccessory        56080
# GamingAccessory        42228
# TVVideoSmall           36205
# Game                   28203
# AudioMP3Player         21540
# Camera                 18071
# HomeAudio              17864
# GamingConsole           8304
# CameraStorage           4121
# AudioAccessory          2537
# HomeTheatre              872
# AmplifierReceiver        454
# GameMembershipCards       65
# Name: product_analytic_sub_category, dtype: int64

# %%
Eleckart1['product_analytic_vertical'].value_counts()
# Out:
# MobileSpeaker              59605
# LaptopSpeaker              35362
# PhysicalGame               24604
# AudioMP3Player             21540
# Flash                      15662
# GamingHeadset              13452
# GamePad                    12168
# SelectorBox                11997
# HomeAudioSpeaker           10821
# DSLR                       10814
# VideoGlasses               10404
# RemoteControl              10205
# Lens                        8490
# CameraBattery               8487
# GamingMouse                 7324
# Point & Shoot               5728
# HandheldGamingConsole       5674
# CameraTripod                5159
# FMRadio                     4946
# CameraBag                   4338
# CameraBatteryCharger        4230
# CameraStorageMemoryCard     4121
# VideoPlayer                 3599
# CodeInTheBoxGame            3599
# Binoculars                  3416
# Filter                      2667
# GamingConsole               2630
# Microphone                  2126
# GamingAccessoryKit          2108
# GamingKeyboard              1518
#                            ...
# CameraFilmRolls              808
# Instant Cameras              787
# Telescope                    536
# GamingMemoryCard             532
# SportsAndAction              499
# Strap                        492
# BoomBox                      466
# AmplifierReceiver            454
# CameraAccessory              439
# MicrophoneAccessory          411
# MotionController             387
# Camcorders                   243
# GamingSpeaker                234
# Dock                         222
# HiFiSystem                   204
# DockingStation               155
# CameraMount                  151
# GameValueCards                65
# CameraEyeCup                  60
# CameraBatteryGrip             46
# SoundMixer                    39
# DJController                  31
# CoolingPad                    25
# CameraHousing                 18
# CameraMicrophone              16
# ExtensionTube                 15
# Softbox                       10
# SlingBox                       2
# FlashShoeAdapter               1
# GamingChargingStation          1
# Name: product_analytic_vertical, Length: 67, dtype: int64

# %% [markdown]
# ### Checking for columns with negative entries

# %%
Eleckart1['product_procurement_sla'].describe()
# Out:
# count    331511.000000
# mean          4.798794
# std          48.045366
# min          -1.000000
# 25%           2.000000
# 50%           2.000000
# 75%           3.000000
# max        1000.000000
# Name: product_procurement_sla, dtype: float64

# %% [markdown]
# #### There are some negative values that have to be removed

# %%
Eleckart1['deliverybdays'].describe()
# Out:
# count    331511.000000
# mean          4.584886
# std           3.394486
# min         -98.000000
# 25%           3.000000
# 50%           4.000000
# 75%           6.000000
# max         238.000000
# Name: deliverybdays, dtype: float64

# %% [markdown]
# #### Negative values exist

# %%
Eleckart1['deliverycdays'].describe()
# Out:
# count    331511.000000
# mean          5.272757
# std           8.508975
# min        -908.000000
# 25%           3.000000
# 50%           5.000000
# 75%           7.000000
# max         278.000000
# Name: deliverycdays, dtype: float64

# %% [markdown]
# #### Negative values exist

# %%
#Replacing all negatives values in the dataframe with zero
Eleckart1[Eleckart1['deliverybdays'] < 0]=0
Eleckart1[Eleckart1['deliverycdays'] < 0]=0
Eleckart1[Eleckart1['product_procurement_sla'] < 0]=0

# %%
Eleckart1
# Out:
#                    fsn_id           order_date  Year  Month      order_id  \
# 706      ACCCX3SU22JG8NJX  2015-10-26 13:06:37  2015     10  3.419100e+15
# 9726     ACCDF2Z7KXGSZEP7  2016-02-03 14:39:53  2016      2  4.415891e+15
# 11094    ACCDFYZ479GFENYC  2016-04-27 01:33:04  2016      4  4.418233e+15
# 11693    ACCDFZEJMYKKUZ8J  2015-10-18 18:14:05  2015     10  3.420272e+15
# 12883    ACCDH7MFZJGRWJCW  2015-10-16 18:27:57  2015     10  3.418556e+15
# 15202    ACCDHNVH8RDQQUBD  2016-01-21 15:00:47  2016      1  2.424488e+15
# 21236    ACCDPYMYWPCZJB6N  2015-11-20 17:35:04  2015     11  1.423603e+15
# 22621    ACCDQGZS3EK5WVR5  2016-04-27 11:56:41  2016      4  3.418113e+15
# 25121    ACCDR62K6HG3SENW  2016-04-27 00:42:56  2016      4  1.431577e+15
# 25979    ACCDRWPFRHEPRTKX  2016-02-21 20:59:09  2016      2  2.419580e+15
# 27551    ACCDTREV54TU7YFE  2016-02-02 15:05:55  2016      2  1.417892e+15
# 30064    ACCDVUZFPGSGGYRD  2015-10-19 16:02:27  2015     10  2.421056e+15
# 31246    ACCDW75GEJGVGFV7  2015-10-01 23:55:39  2015     10  4.405783e+15
# 36049    ACCDXEGXG8HJUCSK  2016-02-22 13:58:19  2016      2  4.417935e+15
# 36692                                CE        EntertainmentSmall
# 37496                                CE        EntertainmentSmall
# 40872                                 0                         0
# 41132                                CE        EntertainmentSmall
# 41133                                CE        EntertainmentSmall
# 41134                                CE        EntertainmentSmall
# 41203                                CE        EntertainmentSmall
# 41460                                CE        EntertainmentSmall
# 41660                                CE        EntertainmentSmall
# 45672                                CE           CameraAccessory
# 45689                                CE           CameraAccessory
# 45931                                CE           CameraAccessory
# 49655                                CE            GamingHardware
# 49675                                CE            GamingHardware
# ...                                 ...                       ...
# 1452731                              CE        EntertainmentSmall
# 1456159                              CE            GamingHardware
# 1457023                              CE        EntertainmentSmall
# 1462302                              CE        EntertainmentSmall
# 1463082                              CE        EntertainmentSmall
# 1464700                              CE           CameraAccessory
# 1469941                              CE        EntertainmentSmall
# 1473860                              CE        EntertainmentSmall
# 1474653                              CE        EntertainmentSmall
# 1474985                              CE            GamingHardware
# 1480910                              CE            GamingHardware
# 1483330                              CE            GamingHardware
# 1483997                              CE           CameraAccessory
# 1484164                              CE           CameraAccessory
# 1484527                              CE           CameraAccessory
# 1484909                              CE           CameraAccessory
# 1487025                              CE           CameraAccessory
# 1487115                              CE           CameraAccessory
# 1488292                              CE            GamingHardware
# 1488789                              CE        EntertainmentSmall
# 1489720                              CE            GamingHardware
# 1489810                              CE            GamingHardware
# 1491461                              CE        EntertainmentSmall
# 1497566                              CE            GamingHardware
# 1498266                              CE           CameraAccessory
# 1502549                              CE        EntertainmentSmall
# 1508407                              CE        EntertainmentSmall
# 1516675                               0                         0
# 1518134                              CE                    Camera
# 1524920                               0                         0
#
#         product_analytic_sub_category product_analytic_vertical product_mrp  \
# 706                   CameraAccessory             CameraBattery      1545.0
# 9726                  GamingAccessory                   GamePad       384.0
# 11094                 CameraAccessory      CameraBatteryCharger       306.0
# 11693                         Speaker             LaptopSpeaker      5999.0
# 12883                 GamingAccessory                   GamePad       410.0
# 15202                         Speaker             MobileSpeaker      4999.0
# 21236                 CameraAccessory             CameraBattery      2999.0
# 22621                         Speaker             MobileSpeaker      7999.0
# 25121                 GamingAccessory            GamingKeyboard      1670.0
# 25979                       HomeAudio                      Dock       999.0
# 27551                 GamingAccessory               GamingMouse      1370.0
# 30064                         Speaker             LaptopSpeaker       750.0
# 31246                         Speaker             LaptopSpeaker       500.0
# 36049                         Speaker             LaptopSpeaker      1000.0
# 36050                         Speaker             LaptopSpeaker      1000.0
# 36457                         Speaker             LaptopSpeaker      1000.0
# 36692                         Speaker             LaptopSpeaker       999.0
# 37496                         Speaker             MobileSpeaker      2999.0
# 40872                               0                         0         0.0
# 41132                         Speaker             MobileSpeaker      8999.0
# 41133                         Speaker             MobileSpeaker      8999.0
# 41134                         Speaker             MobileSpeaker      8999.0
# 41203                         Speaker             MobileSpeaker      8999.0
# 41460                         Speaker             MobileSpeaker      8999.0
# 41660                         Speaker             MobileSpeaker      8999.0
# 45672                 CameraAccessory       CameraRemoteControl      1200.0
# 45689                 CameraAccessory       CameraRemoteControl      1200.0
# 45931                 CameraAccessory      CameraBatteryCharger       899.0
# 49655                 GamingAccessory                   GamePad       799.0
# 49675                 GamingAccessory                   GamePad       799.0
# ...                               ...                       ...         ...
# 1452731                       Speaker             MobileSpeaker      7999.0
# 1456159               GamingAccessory               GamingMouse      1370.0
# 1457023                     HomeAudio          HomeAudioSpeaker      3779.0
# 1462302                       Speaker             LaptopSpeaker       399.0
# 1463082                       Speaker             LaptopSpeaker       599.0
# 1464700                 CameraStorage   CameraStorageMemoryCard       299.0
# 1469941                       Speaker             MobileSpeaker      1999.0
# 1473860                       Speaker             MobileSpeaker      3490.0
# 1474653                       Speaker             LaptopSpeaker      1599.0
# 1474985               GamingAccessory               GamingMouse       799.0
# 1480910               GamingAccessory                   GamePad       250.0
# 1483330               GamingAccessory             GamingHeadset       999.0
# 1483997               CameraAccessory              CameraTripod      1000.0
# 1484164               CameraAccessory              CameraTripod      1990.0
# 1484527               CameraAccessory              CameraTripod      1490.0
# 1484909               CameraAccessory              CameraTripod      1399.0
# 1487025               CameraAccessory              CameraTripod      1990.0
# 1487115               CameraAccessory              CameraTripod      1990.0
# 1488292               GamingAccessory       TVOutCableAccessory       799.0
# 1488789                       Speaker             MobileSpeaker       999.0
# 1489720               GamingAccessory                   GamePad      1599.0
# 1489810               GamingAccessory                   GamePad      1799.0
# 1491461                       Speaker             LaptopSpeaker       799.0
# 1497566               GamingAccessory                   GamePad      3000.0
# 1498266               CameraAccessory                     Flash      1299.0
# 1502549                       Speaker             LaptopSpeaker     11990.0
# 1508407                AudioMP3Player            AudioMP3Player      1669.0
# 1516675                             0                         0         0.0
# 1518134                        Camera                      DSLR     40000.0
# 1524920                             0                         0         0.0
#
#         product_procurement_sla  Day  Week
# 706                           1   26    44
# 9726                          3    3     5
# 11094                         1   27    17
# 11693                         1   18    42
# 12883                         1   16    42
# 15202                         4   21     3
# 21236                         5   20    47
# 22621                         2   27    17
# 25121                         4   27    17
# 25979                         2   21     7
# 27551                         0    2     5
# 30064                         1   19    43
# 31246                         1    1    40
# 36049                         2   22     8
# 36050                         2   27    17
# 36457                         2   31     4
# 36692                         3   23    43
# 37496                         3   20    43
# 40872                         0    0     0
# 41132                         1   11     2
# 41133                         1   13     2
# 41134                         1   27    17
# 41203                         1   17    42
# 41460                         1   27    17
# 41660                         1   21     7
# 45672                         1   10    41
# 45689                         1    3    13
# 45931                         2   30    44
# 49655                         2   17    42
# 49675                         2   24    43
# ...                         ...  ...   ...
# 1452731                       2   27    17
# 1456159                       0   27    17
# 1457023                       1   22     8
# 1462302                       3   30    40
# 1463082                       5    9    37
# 1464700                       2   27    17
# 1469941                       2    7    37
# 1473860                       1   30    40
# 1474653                       3   24    39
# 1474985                       5   27    17
# 1480910                       2   26    17
# 1483330                       4   30    40
# 1483997                       1   27    17
# 1484164                       1   22     8
# 1484527                       1   27    17
# 1484909                       3   16    11
# 1487025                       2   27    17
# 1487115                       2    4     5
# 1488292                       1   27    17
# 1488789                       2    7    37
# 1489720                       2   27    17
# 1489810                       0   12     6
# 1491461                       4   24    39
# 1497566                       2    9    14
# 1498266                       4   20    38
# 1502549                       5   27    17
# 1508407                       4   27    17
# 1516675                       0    0     0
# 1518134                       2   27    17
# 1524920                       0    0     0
#
# [331511 rows x 22 columns]

# %%
Eleckart1['deliverybdays'] = pd.to_numeric(Eleckart1['deliverybdays'], errors='coerce')
Eleckart1['deliverycdays'] = pd.to_numeric(Eleckart1['deliverycdays'], errors='coerce')
Eleckart1['sla'] = pd.to_numeric(Eleckart1['sla'], errors='coerce')

# %%
Eleckart1['delivery_on_time'] = Eleckart1['sla'] - (Eleckart1['deliverybdays']+Eleckart1['deliverycdays']+Eleckart1['product_procurement_sla'])

# %%
def delivery_status (delivery_on_time):
    if delivery_on_time < 0:
        return "Delayed"
    elif delivery_on_time > 0:
        return "Early"
    elif delivery_on_time == 0:
        return "On Time"

Eleckart1['delivery_status'] = Eleckart1['delivery_on_time'].apply(delivery_status)

# %%
# Exploring the delivery status
sns.countplot(x='delivery_status',data=Eleckart1)

# %%
Eleckart1.drop('delivery_on_time',axis=1, inplace=True)

# %%
Eleckart1.head()
# Out:
#                  fsn_id           order_date  Year  Month      order_id  \
# 706    ACCCX3SU22JG8NJX  2015-10-26 13:06:37  2015     10  3.419100e+15
# 9726   ACCDF2Z7KXGSZEP7  2016-02-03 14:39:53  2016      2  4.415891e+15
# 11094  ACCDFYZ479GFENYC  2016-04-27 01:33:04  2016      4  4.418233e+15
# 11693  ACCDFZEJMYKKUZ8J  2015-10-18 18:14:05  2015     10  3.420272e+15
# 12883  ACCDH7MFZJGRWJCW  2015-10-16 18:27:57  2015     10  3.418556e+15
#
#        order_item_id     gmv  units  deliverybdays  deliverycdays  ...  \
# 706     3.419100e+15   470.0      1            5.0            6.0  ...
# 9726    4.415891e+15   384.0      1            5.0            6.0  ...
# 11094   4.418233e+15   306.0      1            4.0            5.0  ...
# 11693   3.420272e+15  2442.0      1           12.0           14.0  ...
# 12883   3.418556e+15   268.0      1            6.0            7.0  ...
#
#                       pincode  product_analytic_super_category  \
# 706    -7.82411064429225E+018                               CE
# 9726   -8.03408849241778E+018                               CE
# 11094  -7.84370947414129E+018                               CE
# 11693     5.186887196114E+018                               CE
# 12883   7.47752021619299E+018                               CE
#
#       product_analytic_category product_analytic_sub_category  \
# 706             CameraAccessory               CameraAccessory
# 9726             GamingHardware               GamingAccessory
# 11094           CameraAccessory               CameraAccessory
# 11693        EntertainmentSmall                       Speaker
# 12883            GamingHardware               GamingAccessory
#
#       product_analytic_vertical product_mrp product_procurement_sla Day  Week  \
# 706               CameraBattery      1545.0                       1  26    44
# 9726                    GamePad       384.0                       3   3     5
# 11094      CameraBatteryCharger       306.0                       1  27    17
# 11693             LaptopSpeaker      5999.0                       1  18    42
# 12883                   GamePad       410.0                       1  16    42
#
#        delivery_status
# 706            Delayed
# 9726           Delayed
# 11094          Delayed
# 11693          Delayed
# 12883          Delayed
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Creating Separate datasets for Camera Accessories, Gaming Accessory and Home Audio

# %%
print(Eleckart1.product_analytic_sub_category.isnull().sum())

Eleckart1['product_analytic_sub_category'].replace(r'\s+', np.nan,regex=True,inplace=True)
Eleckart1=Eleckart1[Eleckart1['product_analytic_sub_category']!=0]

df1=Eleckart1.product_analytic_sub_category.str.contains('CameraAccessory')
CameraAccessory=Eleckart1[df1]

df2=Eleckart1.product_analytic_sub_category.str.contains('GamingAccessory')
GamingAccessory=Eleckart1[df2]

df3=Eleckart1.product_analytic_sub_category.str.contains('HomeAudio')
HomeAudio=Eleckart1[df3]
# Out:
# 0

# %%
CameraAccessory['s1_fact.order_payment_type']
# Out:
# 706        Prepaid
# 11094      Prepaid
# 21236      Prepaid
# 45672      Prepaid
# 45689      Prepaid
# 45931      Prepaid
# 61269      Prepaid
# 80855      Prepaid
# 81271      Prepaid
# 82242      Prepaid
# 83775      Prepaid
# 98345      Prepaid
# 222538     Prepaid
# 235120     Prepaid
# 241480     Prepaid
# 242932     Prepaid
# 274508     Prepaid
# 339479     Prepaid
# 356771     Prepaid
# 671077     Prepaid
# 694069     Prepaid
# 706006     Prepaid
# 783868     Prepaid
# 783881     Prepaid
# 783908     Prepaid
# 783923     Prepaid
# 783936     Prepaid
# 783970     Prepaid
# 783971     Prepaid
# 784007     Prepaid
#             ...
# 1363132    Prepaid
# 1363269    Prepaid
# 1373045    Prepaid
# 1375622    Prepaid
# 1376142    Prepaid
# 1379492    Prepaid
# 1379986    Prepaid
# 1387675    Prepaid
# 1390826    Prepaid
# 1391148    Prepaid
# 1391151    Prepaid
# 1395725    Prepaid
# 1397815    Prepaid
# 1398127    Prepaid
# 1398186    Prepaid
# 1398272    Prepaid
# 1398316    Prepaid
# 1398334    Prepaid
# 1398479    Prepaid
# 1398480    Prepaid
# 1398686    Prepaid
# 1448156    Prepaid
# 1449026    Prepaid
# 1483997    Prepaid
# 1484164    Prepaid
# 1484527    Prepaid
# 1484909    Prepaid
# 1487025    Prepaid
# 1487115    Prepaid
# 1498266    Prepaid
# Name: s1_fact.order_payment_type, Length: 54932, dtype: object

# %%
a=CameraAccessory.pivot_table(values='gmv',index='Week',aggfunc='sum')
plt.figure(figsize=(20,20))
a.plot.line(y='gmv',use_index=True,figsize=(15,10), grid=True)
plt.xticks(np.arange(0,50,step=1))
# Out:
# ([<matplotlib.axis.XTick at 0x1d3de788e80>,
#   <matplotlib.axis.XTick at 0x1d3de79bf28>,
#   <matplotlib.axis.XTick at 0x1d3e493dac8>,
#   <matplotlib.axis.XTick at 0x1d3e4947518>,
#   <matplotlib.axis.XTick at 0x1d3e4947c50>,
#   <matplotlib.axis.XTick at 0x1d3e494f198>,
#   <matplotlib.axis.XTick at 0x1d3de79bc50>,
#   <matplotlib.axis.XTick at 0x1d3e495fa58>,
#   <matplotlib.axis.XTick at 0x1d3e495ff28>,
#   <matplotlib.axis.XTick at 0x1d3e495f198>,
#   <matplotlib.axis.XTick at 0x1d3e494fdd8>,
#   <matplotlib.axis.XTick at 0x1d3e49680f0>,
#   <matplotlib.axis.XTick at 0x1d3e4968668>,
#   <matplotlib.axis.XTick at 0x1d3e4968b38>,
#   <matplotlib.axis.XTick at 0x1d3e6a920b8>,
#   <matplotlib.axis.XTick at 0x1d3e6a92518>,
#   <matplotlib.axis.XTick at 0x1d3e6a929e8>,
#   <matplotlib.axis.XTick at 0x1d3e6a92eb8>,
#   <matplotlib.axis.XTick at 0x1d3e6a92f98>,
#   <matplotlib.axis.XTick at 0x1d3e4968710>,
#   <matplotlib.axis.XTick at 0x1d3e495f320>,
#   <matplotlib.axis.XTick at 0x1d3e6a9a668>,
#   <matplotlib.axis.XTick at 0x1d3e6a9ab38>,
#   <matplotlib.axis.XTick at 0x1d3e6aa40b8>,
#   <matplotlib.axis.XTick at 0x1d3e6aa4518>,
#   <matplotlib.axis.XTick at 0x1d3e6aa49e8>,
#   <matplotlib.axis.XTick at 0x1d3e6aa4eb8>,
#   <matplotlib.axis.XTick at 0x1d3e6aac3c8>,
#   <matplotlib.axis.XTick at 0x1d3e6aa4470>,
#   <matplotlib.axis.XTick at 0x1d3e6a9a2e8>,
#   <matplotlib.axis.XTick at 0x1d3e6aac668>,
#   <matplotlib.axis.XTick at 0x1d3e6aacac8>,
#   <matplotlib.axis.XTick at 0x1d3e6aace80>,
#   <matplotlib.axis.XTick at 0x1d3e6ab54a8>,
#   <matplotlib.axis.XTick at 0x1d3e6ab5978>,
#   <matplotlib.axis.XTick at 0x1d3e6ab5e48>,
#   <matplotlib.axis.XTick at 0x1d3e6abc358>,
#   <matplotlib.axis.XTick at 0x1d3e6ab5940>,
#   <matplotlib.axis.XTick at 0x1d3e4957e80>,
#   <matplotlib.axis.XTick at 0x1d3e6a9a9b0>,
#   <matplotlib.axis.XTick at 0x1d3e6abcac8>,
#   <matplotlib.axis.XTick at 0x1d3e6abce80>,
#   <matplotlib.axis.XTick at 0x1d3e6ac74a8>,
#   <matplotlib.axis.XTick at 0x1d3e6ac7978>,
#   <matplotlib.axis.XTick at 0x1d3e6ac7e48>,
#   <matplotlib.axis.XTick at 0x1d3e6ace358>,
#   <matplotlib.axis.XTick at 0x1d3e6ace828>,
#   <matplotlib.axis.XTick at 0x1d3e6ac7f28>,
#   <matplotlib.axis.XTick at 0x1d3e6abc400>,
#   <matplotlib.axis.XTick at 0x1d3e6ace780>],
#  <a list of 50 Text xticklabel objects>)

# %%
b=GamingAccessory.pivot_table(values='gmv',index='Week',aggfunc='sum')
b.plot.line(y='gmv',use_index=True,figsize=(15,10), grid=True)
plt.xticks(np.arange(0,50,step=1))
# Out:
# ([<matplotlib.axis.XTick at 0x1d3dc1a1f60>,
#   <matplotlib.axis.XTick at 0x1d3dc15f0b8>,
#   <matplotlib.axis.XTick at 0x1d3dc1c5b38>,
#   <matplotlib.axis.XTick at 0x1d3dc1d3588>,
#   <matplotlib.axis.XTick at 0x1d3dc1d3cc0>,
#   <matplotlib.axis.XTick at 0x1d3dc1da1d0>,
#   <matplotlib.axis.XTick at 0x1d3dc194f98>,
#   <matplotlib.axis.XTick at 0x1d3dc1e2978>,
#   <matplotlib.axis.XTick at 0x1d3dc1e2e48>,
#   <matplotlib.axis.XTick at 0x1d3dc1eb358>,
#   <matplotlib.axis.XTick at 0x1d3dc1eb828>,
#   <matplotlib.axis.XTick at 0x1d3dc1ebcf8>,
#   <matplotlib.axis.XTick at 0x1d3dc1f3208>,
#   <matplotlib.axis.XTick at 0x1d3dc1eb908>,
#   <matplotlib.axis.XTick at 0x1d3dc1e2cc0>,
#   <matplotlib.axis.XTick at 0x1d3dc1da518>,
#   <matplotlib.axis.XTick at 0x1d3dc1f3160>,
#   <matplotlib.axis.XTick at 0x1d3dc1f3e48>,
#   <matplotlib.axis.XTick at 0x1d3dc1fc358>,
#   <matplotlib.axis.XTick at 0x1d3dc1fc828>,
#   <matplotlib.axis.XTick at 0x1d3dc1fccf8>,
#   <matplotlib.axis.XTick at 0x1d3ddce5208>,
#   <matplotlib.axis.XTick at 0x1d3ddce56d8>,
#   <matplotlib.axis.XTick at 0x1d3dc1fcda0>,
#   <matplotlib.axis.XTick at 0x1d3dc1f32e8>,
#   <matplotlib.axis.XTick at 0x1d3ddce57b8>,
#   <matplotlib.axis.XTick at 0x1d3ddce5e48>,
#   <matplotlib.axis.XTick at 0x1d3ddcef358>,
#   <matplotlib.axis.XTick at 0x1d3ddcef828>,
#   <matplotlib.axis.XTick at 0x1d3ddcefcf8>,
#   <matplotlib.axis.XTick at 0x1d3ddcf6208>,
#   <matplotlib.axis.XTick at 0x1d3ddcf66d8>,
#   <matplotlib.axis.XTick at 0x1d3ddcf6ba8>,
#   <matplotlib.axis.XTick at 0x1d3ddcef400>,
#   <matplotlib.axis.XTick at 0x1d3dc1f3ef0>,
#   <matplotlib.axis.XTick at 0x1d3ddcf6e48>,
#   <matplotlib.axis.XTick at 0x1d3ddd012e8>,
#   <matplotlib.axis.XTick at 0x1d3ddd017b8>,
#   <matplotlib.axis.XTick at 0x1d3ddd01c88>,
#   <matplotlib.axis.XTick at 0x1d3ddd09198>,
#   <matplotlib.axis.XTick at 0x1d3ddd09668>,
#   <matplotlib.axis.XTick at 0x1d3ddd09b38>,
#   <matplotlib.axis.XTick at 0x1d3ddd09a90>,
#   <matplotlib.axis.XTick at 0x1d3ddd01be0>,
#   <matplotlib.axis.XTick at 0x1d3ddcf6908>,
#   <matplotlib.axis.XTick at 0x1d3ddd112e8>,
#   <matplotlib.axis.XTick at 0x1d3ddd117b8>,
#   <matplotlib.axis.XTick at 0x1d3ddd11c88>,
#   <matplotlib.axis.XTick at 0x1d3ddd19198>,
#   <matplotlib.axis.XTick at 0x1d3ddd19668>],
#  <a list of 50 Text xticklabel objects>)

# %%
c=HomeAudio.pivot_table(values='gmv',index='Week',aggfunc='sum')
plt.figure(figsize=(20,20))
c.plot.line(y='gmv',use_index=True,figsize=(15,10), grid=True)
plt.xticks(np.arange(0,50,step=1))
# Out:
# ([<matplotlib.axis.XTick at 0x1d3ddd77828>,
#   <matplotlib.axis.XTick at 0x1d3ddd773c8>,
#   <matplotlib.axis.XTick at 0x1d3ddd90d30>,
#   <matplotlib.axis.XTick at 0x1d3ddd9a2b0>,
#   <matplotlib.axis.XTick at 0x1d3ddd9a7b8>,
#   <matplotlib.axis.XTick at 0x1d3ddd9ac88>,
#   <matplotlib.axis.XTick at 0x1d3de6f2198>,
#   <matplotlib.axis.XTick at 0x1d3ddd9a898>,
#   <matplotlib.axis.XTick at 0x1d3ddd90f60>,
#   <matplotlib.axis.XTick at 0x1d3de6f2160>,
#   <matplotlib.axis.XTick at 0x1d3ddd77278>,
#   <matplotlib.axis.XTick at 0x1d3de702a90>,
#   <matplotlib.axis.XTick at 0x1d3de6fbe48>,
#   <matplotlib.axis.XTick at 0x1d3ddd90c18>,
#   <matplotlib.axis.XTick at 0x1d3de702b70>,
#   <matplotlib.axis.XTick at 0x1d3de70d160>,
#   <matplotlib.axis.XTick at 0x1d3de70d5c0>,
#   <matplotlib.axis.XTick at 0x1d3de70da90>,
#   <matplotlib.axis.XTick at 0x1d3de70df60>,
#   <matplotlib.axis.XTick at 0x1d3de713470>,
#   <matplotlib.axis.XTick at 0x1d3de713940>,
#   <matplotlib.axis.XTick at 0x1d3de713e10>,
#   <matplotlib.axis.XTick at 0x1d3de7137b8>,
#   <matplotlib.axis.XTick at 0x1d3de70d240>,
#   <matplotlib.axis.XTick at 0x1d3de70dbe0>,
#   <matplotlib.axis.XTick at 0x1d3de71c550>,
#   <matplotlib.axis.XTick at 0x1d3de71ca20>,
#   <matplotlib.axis.XTick at 0x1d3de71cef0>,
#   <matplotlib.axis.XTick at 0x1d3de725400>,
#   <matplotlib.axis.XTick at 0x1d3de7258d0>,
#   <matplotlib.axis.XTick at 0x1d3de725da0>,
#   <matplotlib.axis.XTick at 0x1d3de725978>,
#   <matplotlib.axis.XTick at 0x1d3de71cd68>,
#   <matplotlib.axis.XTick at 0x1d3de70d1d0>,
#   <matplotlib.axis.XTick at 0x1d3de72e438>,
#   <matplotlib.axis.XTick at 0x1d3de72ea20>,
#   <matplotlib.axis.XTick at 0x1d3de72eef0>,
#   <matplotlib.axis.XTick at 0x1d3de736400>,
#   <matplotlib.axis.XTick at 0x1d3de7368d0>,
#   <matplotlib.axis.XTick at 0x1d3de736da0>,
#   <matplotlib.axis.XTick at 0x1d3de7402b0>,
#   <matplotlib.axis.XTick at 0x1d3de736e80>,
#   <matplotlib.axis.XTick at 0x1d3de72e898>,
#   <matplotlib.axis.XTick at 0x1d3de740550>,
#   <matplotlib.axis.XTick at 0x1d3de740a20>,
#   <matplotlib.axis.XTick at 0x1d3de740ef0>,
#   <matplotlib.axis.XTick at 0x1d3de748400>,
#   <matplotlib.axis.XTick at 0x1d3de7488d0>,
#   <matplotlib.axis.XTick at 0x1d3de748da0>,
#   <matplotlib.axis.XTick at 0x1d3de7502b0>],
#  <a list of 50 Text xticklabel objects>)

# %%
#Performing linear regression for CameraAccessory
CameraAccessory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54932 entries, 706 to 1498266
# Data columns (total 23 columns):
# fsn_id                             54932 non-null object
# order_date                         54932 non-null object
# Year                               54932 non-null int64
# Month                              54932 non-null int64
# order_id                           54932 non-null float64
# order_item_id                      54932 non-null float64
# gmv                                54932 non-null float64
# units                              54932 non-null int64
# deliverybdays                      54932 non-null float64
# deliverycdays                      54932 non-null float64
# s1_fact.order_payment_type         54932 non-null object
# sla                                54932 non-null int64
# cust_id                            54932 non-null object
# pincode                            54932 non-null object
# product_analytic_super_category    54932 non-null object
# product_analytic_category          54932 non-null object
# product_analytic_sub_category      54932 non-null object
# product_analytic_vertical          54932 non-null object
# product_mrp                        54932 non-null float64
# product_procurement_sla            54932 non-null int64
# Day                                54932 non-null int64
# Week                               54932 non-null int64
# delivery_status                    54932 non-null object
# dtypes: float64(6), int64(7), object(10)
# memory usage: 10.1+ MB

# %%
CameraAccessory_data = CameraAccessory[['Year','Month','gmv','units','deliverybdays','deliverycdays','s1_fact.order_payment_type','sla','pincode','product_analytic_super_category','product_analytic_category','product_analytic_sub_category','product_analytic_vertical','product_mrp','product_procurement_sla','Day','Week','delivery_status']]

# %%
s1_fact_order_payment_type = pd.get_dummies(CameraAccessory_data['s1_fact.order_payment_type'], drop_first = True)
CameraAccessory_data = pd.concat([CameraAccessory_data, s1_fact_order_payment_type], axis = 1)

pincode = pd.get_dummies(CameraAccessory_data['pincode'], drop_first = True)
CameraAccessory_data = pd.concat([CameraAccessory_data, pincode], axis = 1)

product_analytic_super_category  = pd.get_dummies(CameraAccessory_data['product_analytic_super_category'], drop_first = True)
CameraAccessory_data = pd.concat([CameraAccessory_data,product_analytic_super_category], axis = 1)
                            
product_analytic_category = pd.get_dummies(CameraAccessory_data['product_analytic_category'], drop_first = True)
CameraAccessory_data = pd.concat([CameraAccessory_data,product_analytic_category], axis = 1)
                            
product_analytic_vertical = pd.get_dummies(CameraAccessory_data['product_analytic_vertical'], drop_first = True)
CameraAccessory_data = pd.concat([CameraAccessory_data,product_analytic_vertical], axis = 1)
                            
delivery_status = pd.get_dummies(CameraAccessory_data['delivery_status'], drop_first = True)
CameraAccessory_data = pd.concat([CameraAccessory_data,delivery_status], axis = 1)

# %%
s1_fact_order_payment_type = pd.get_dummies(CameraAccessory_data['s1_fact.order_payment_type'], drop_first = True)
CameraAccessory_data = pd.concat([CameraAccessory_data, s1_fact_order_payment_type], axis = 1)

# %%
CameraAccessory_data.head()
# Out:
#        Year  Month     gmv  units  deliverybdays  deliverycdays  \
# 706    2015     10   470.0      1            5.0            6.0
# 11094  2016      4   306.0      1            4.0            5.0
# 21236  2015     11  1040.0      1            8.0            9.0
# 45672  2015     10   620.0      1            7.0            9.0
# 45689  2016      4   620.0      1            7.0            9.0
#
#       s1_fact.order_payment_type  sla                 pincode  \
# 706                      Prepaid    7  -7.82411064429225E+018
# 11094                    Prepaid    8  -7.84370947414129E+018
# 21236                    Prepaid    7  -7.59332381794251E+018
# 45672                    Prepaid    8  -3.52497864105926E+018
# 45689                    Prepaid    8  -3.52497864105926E+018
#
#       product_analytic_super_category  ... Filter Flash FlashShoeAdapter  \
# 706                                CE  ...      0     0                0
# 11094                              CE  ...      0     0                0
# 21236                              CE  ...      0     0                0
# 45672                              CE  ...      0     0                0
# 45689                              CE  ...      0     0                0
#
#        Lens  Softbox  Strap  Telescope Early  On Time  Prepaid
# 706       0        0      0          0     0        0        1
# 11094     0        0      0          0     0        0        1
# 21236     0        0      0          0     0        0        1
# 45672     0        0      0          0     0        0        1
# 45689     0        0      0          0     0        0        1
#
# [5 rows x 4904 columns]

# %%
import sys
sys.getsizeof(CameraAccessory_data)
# Out:
# 297942153

# %%
from sklearn.model_selection import train_test_split

# We specify this so that the train and test data set always have the same rows, respectively
np.random.seed(0)
df_train, df_test = train_test_split(CameraAccessory_data, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
#Inspecting train dataset for CameraAccessory
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38452 entries, 1143416 to 1169670
# Columns: 155986 entries, fsn_id to On Time
# dtypes: float64(6), int64(7), object(10), uint8(155963)
# memory usage: 5.6+ GB

# %%
df_train.describe
# Out:
# <bound method NDFrame.describe of          Year  Month  units  deliverybdays  deliverycdays  \
# 1143416  2016      5      1            7.0            8.0
# 1272421  2016      6      1            4.0            5.0
# 1018874  2016      4      1            5.0            5.0
# 984600   2016      4      1            2.0            2.0
# 1074030  2016      5      1            3.0            3.0
# 1137284  2016      5      1            4.0            5.0
# 1087231  2016      5      1            5.0            6.0
# 1241944  2016      6      1            6.0            7.0
# 1253474  2016      6      1            5.0            6.0
# 1122856  2016      5      1            5.0            6.0
# 1057915  2016      4      1            3.0            3.0
# 948689   2016      4      1            6.0            7.0
# 945722   2016      4      1            1.0            1.0
# 950315   2016      4      1            6.0            7.0
# 1122259  2016      5      1            5.0            6.0
# 1272427  2016      6      1            3.0            3.0
# 1229108  2016      6      1            4.0            5.0
# 1256830  2016      6      1            5.0            5.0
# 938086   2016      4      1            7.0            8.0
# 1123386  2016      5      1            5.0            5.0
# 1216493  2016      5      1            5.0            5.0
# 997945   2016      4      1            8.0           10.0
# 1319894  2016      6      1            1.0            1.0
# 985404   2016      5      1            6.0            8.0
# 986989   2016      4      1            4.0            5.0
# 1123050  2016      5      1            5.0            6.0
# 1250168  2016      6      1            6.0            7.0
# 1124872  2016      5      1            4.0            5.0
# 1101051  2016      5      1            4.0            4.0
# 968676   2016      4      1            3.0            4.0
# ...       ...    ...    ...            ...            ...
# 1101810  2016      5      1            6.0            7.0
# 1125386  2016      5      1            3.0            4.0
# 1065868  2016      4      1            5.0            5.0
# 957187   2016      4      1            5.0            6.0
# 1072078  2016      5      1            2.0            3.0
# 959143   2016      4      1            4.0            5.0
# 1005262  2016      4      1            7.0            8.0
# 1169825  2016      5      1            2.0            3.0
# 1239456  2016      6      1            4.0            4.0
# 1247350  2016      6      1            5.0            6.0
# 965916   2016      4      1            4.0            4.0
# 1020579  2016      4      1            5.0            6.0
# 1248116  2016      6      1            4.0            5.0
# 1100364  2016      5      1            6.0            7.0
# 1080172  2016      5      1            3.0            4.0
# 1016197                    Prepaid    8  3.34233e+18
# 1013346                    Prepaid   10 -6.03266e+18
# 786447                     Prepaid   10 -3.20344e+18
# 987364                     Prepaid    4 -6.94779e+18
# 997089                     Prepaid    3  8.08103e+18
# 1169670                        COD    7 -8.28433e+18
#
#         product_analytic_super_category product_analytic_category  ...  \
# 1143416                              CE           CameraAccessory  ...
# 1272421                              CE           CameraAccessory  ...
# 1018874                              CE           CameraAccessory  ...
# 984600                               CE           CameraAccessory  ...
# 1074030                              CE           CameraAccessory  ...
# 1137284                              CE           CameraAccessory  ...
# 1087231                              CE           CameraAccessory  ...
# 1241944                              CE           CameraAccessory  ...
# 1253474                              CE           CameraAccessory  ...
# 1122856                              CE           CameraAccessory  ...
# 1057915                              CE           CameraAccessory  ...
# 948689                               CE           CameraAccessory  ...
# 945722                               CE           CameraAccessory  ...
# 950315                               CE           CameraAccessory  ...
# 1122259                              CE           CameraAccessory  ...
# 1272427                              CE           CameraAccessory  ...
# 1229108                              CE           CameraAccessory  ...
# 1256830                              CE           CameraAccessory  ...
# 938086                               CE           CameraAccessory  ...
# 1123386                              CE           CameraAccessory  ...
# 1216493                              CE           CameraAccessory  ...
# 997945                               CE           CameraAccessory  ...
# 1319894                              CE           CameraAccessory  ...
# 985404                               CE           CameraAccessory  ...
# 986989                               CE           CameraAccessory  ...
# 1123050                              CE           CameraAccessory  ...
# 1250168                              CE           CameraAccessory  ...
# 1124872                              CE           CameraAccessory  ...
# 1101051                              CE           CameraAccessory  ...
# 968676                               CE           CameraAccessory  ...
# ...                                 ...                       ...  ...
# 1101810                              CE           CameraAccessory  ...
# 1125386                              CE           CameraAccessory  ...
# 1065868                              CE           CameraAccessory  ...
# 957187                               CE           CameraAccessory  ...
# 1072078                              CE           CameraAccessory  ...
# 959143                               CE           CameraAccessory  ...
# 1005262                              CE           CameraAccessory  ...
# 1169825                              CE           CameraAccessory  ...
# 1239456                              CE           CameraAccessory  ...
# 1247350                              CE           CameraAccessory  ...
# 965916                               CE           CameraAccessory  ...
# 1020579                              CE           CameraAccessory  ...
# 1248116                              CE           CameraAccessory  ...
# 1100364                              CE           CameraAccessory  ...
# 1080172                              CE           CameraAccessory  ...
# 1244991                              CE           CameraAccessory  ...
# 995878                               CE           CameraAccessory  ...
# 1272746                              CE           CameraAccessory  ...
# 957022                               CE           CameraAccessory  ...
# 1231501                              CE           CameraAccessory  ...
# 996717                               CE           CameraAccessory  ...
# 1076426                              CE           CameraAccessory  ...
# 979482                               CE           CameraAccessory  ...
# 997262                               CE           CameraAccessory  ...
# 1016197                              CE           CameraAccessory  ...
# 1013346                              CE           CameraAccessory  ...
# 786447                               CE           CameraAccessory  ...
# 987364                               CE           CameraAccessory  ...
# 997089                               CE           CameraAccessory  ...
# 1169670                              CE           CameraAccessory  ...
#
#         ExtensionTube Filter  Flash  FlashShoeAdapter  Lens  Softbox Strap  \
# 1143416             0      0      0                 0     1        0     0
# 1272421             0      0      1                 0     0        0     0
# 1018874             0      0      0                 0     0        0     1
# 1250168          0      0        0
# 1124872          0      0        0
# 1101051          0      0        0
# 968676           0      0        0
# ...            ...    ...      ...
# 1101810          0      0        0
# 1125386          0      0        0
# 1065868          1      0        0
# 957187           0      0        0
# 1072078          0      0        0
# 959143           0      0        0
# 1005262          0      0        0
# 1169825          0      0        0
# 1239456          0      0        0
# 1247350          0      0        0
# 965916           0      0        0
# 1020579          0      0        0
# 1248116          0      0        0
# 1100364          0      0        0
# 1080172          0      0        0
# 1244991          0      0        0
# 995878           0      0        0
# 1272746          0      0        0
# 957022           0      0        0
# 1231501          0      0        0
# 996717           0      0        0
# 1076426          0      0        0
# 979482           0      0        0
# 997262           0      0        0
# 1016197          0      0        0
# 1013346          0      0        0
# 786447           0      0        0
# 987364           0      0        0
# 997089           0      0        0
# 1169670          0      0        0
#
# [38452 rows x 4902 columns]>

# %%
y_train = df_train.pop('gmv')
X_train = df_train

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
lm = model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-7d01c7fc8d62> in <module>
# ----> 1 lm = model.fit(X_train,y_train)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     565         # make sure we actually converted to numeric:
#     566         if dtype_numeric and array.dtype.kind == "O":
# --> 567             array = array.astype(np.float64)
#     568         if not allow_nd and array.ndim >= 3:
#     569             raise ValueError("Found array with dim %d. %s expected <= 2."
#
# ValueError: could not convert string to float: 'COD'

# %%
#Build a linear model

import statsmodels.api as sm
X_train_lm = sm.add_constant(X_train)

lr_1 = sm.OLS(y_train, X_train_lm).fit()

lr_1.params
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-106-b15c257abd4a> in <module>
#       2
#       3 import statsmodels.api as sm
# ----> 4 X_train_lm = sm.add_constant(X_train)
#       5
#       6 lr_1 = sm.OLS(y_train, X_train_lm).fit()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tools\tools.py in add_constant(data, prepend, has_constant)
#     268     if _is_using_pandas(data, None) or _is_recarray(data):
#     269         from statsmodels.tsa.tsatools import add_trend
# --> 270         return add_trend(data, trend='c', prepend=prepend, has_constant=has_constant)
#     271
#     272     # Special case for NumPy
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py in add_trend(x, trend, prepend, has_constant)
#      95                 except:
#      96                     return False
# ---> 97             col_const = x.apply(safe_is_const, 0)
#      98         else:
#      99             col_const = np.logical_and(np.any(np.ptp(np.asanyarray(x), axis=0) == 0, axis=0),
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     239             # Create a dummy Series from an empty array
#     240             from pandas import Series
# --> 241             values = self.values
#     242             index = self.obj._get_axis(self.axis)
#     243             labels = self.agg_axis
#
# pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\apply.py in values(self)
#      97     @cache_readonly
#      98     def values(self):
# ---> 99         return self.obj.values
#     100
#     101     @cache_readonly
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in values(self)
#    5323         """
#    5324         self._consolidate_inplace()
# -> 5325         return self._data.as_array(transpose=self._AXIS_REVERSED)
#    5326
#    5327     @property
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in as_array(self, transpose, items)
#     766             arr = np.asarray(mgr.blocks[0].get_values())
#     767         else:
# --> 768             arr = mgr._interleave()
#     769
#     770         return arr.transpose() if transpose else arr
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _interleave(self)
#     785             dtype = 'object'
#     786
# --> 787         result = np.empty(self.shape, dtype=dtype)
#     788
#     789         itemmask = np.zeros(self.shape[0])
#
# MemoryError:
